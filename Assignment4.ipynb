# %% [markdown]
# <a href="https://colab.research.google.com/github/bradynp/CSC221_bprim002/blob/main/Assignment4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# TIY 3-1

names = ['Connor', 'Brendan', 'Jake']

print(names[0])
print(names[1])
print(names[2])

# %%
# TIY 3-2

names = ['Connor', 'Brendan', 'Jake']

message = f"Hey how are you doing {names[0].title()}?"
print(message)

message = f"Hey how are you doing {names[1].title()}?"
print(message)

message = f"Hey how are you doing {names[2].title()}?"
print(message)

# %%
# TIY 3-3

cars = ['Lamborghini', 'Tesla', 'Porsche']

message = f"Hey how are you doing {cars[0].title()}?"
print(message)

message = f"Hey how are you doing {cars[1].title()}?"
print(message)

message = f"Hey how are you doing {cars[2].title()}?"
print(message)

# %%
# TIY 3-4

guests = ['Malcolm X', 'George Lucas', 'Alexander the Great']

name = guests[0].title()
print(f"{name}, would you please come to my dinner tonight?")

name = guests[1].title()
print(f"{name}, my man! Dinner tonight at my house.")

name = guests[2].title()
print(f"{name}, I am having a dinner at my house tonight and I would love for you to come.")

# %%
# TIY 3-5

guests = ['Malcolm X', 'George Lucas', 'Alexander the Great']

name = guests[0].title()
print(f"{name}, would you please come to my dinner tonight?")

name = guests[1].title()
print(f"{name}, my man! Dinner tonight at my house.")

name = guests[2].title()
print(f"{name}, I am having a dinner at my house tonight and I would love for you to come.")

name = guests[1].title()
print(f"\nSorry, {name} can't make it to dinner.")

del(guests[1])
guests.insert(1, 'J.R.R. Tolkein')

# Print the invitations again.
name = guests[0].title()
print(f"\n{name}, would you please come to my dinner tonight?")

name = guests[1].title()
print(f"{name}, my man! Dinner tonight at my house.")

name = guests[2].title()
print(f"{name}, I am having a dinner at my house tonight and I would love for you to come.")

# %%
# TIY 3-6

guests = ['Malcolm X', 'George Lucas', 'Alexander the Great']

name = guests[0].title()
print(f"{name}, would you please come to my dinner tonight?")

name = guests[1].title()
print(f"{name}, my man! Dinner tonight at my house.")

name = guests[2].title()
print(f"{name}, I am having a dinner at my house tonight and I would love for you to come.")

name = guests[1].title()
print(f"\nSorry, {name} can't make it to dinner.")

del(guests[1])
guests.insert(1, 'J.R.R. Tolkein')

# Print the invitations again.
name = guests[0].title()
print(f"\n{name}, would you please come to my dinner tonight?")

name = guests[1].title()
print(f"{name}, my man! Dinner tonight at my house.")

name = guests[2].title()
print(f"{name}, I am having a dinner at my house tonight and I would love for you to come.")

print("\nWe got a bigger table for more guests!")
guests.insert(3, 'Leonardo Da Vinci')
guests.insert(4, 'Napoleon')
guests.append('Lebron James')


name = guests[0].title()
print(f"{name}, would you please come to my dinner tonight?")

name = guests[1].title()
print(f"{name}, my man! Dinner tonight at my house.")

name = guests[2].title()
print(f"{name}, I am having a dinner at my house tonight and I would love for you to come.")

name = guests[3].title()
print(f"{name}, come to my house for dinner tonight, we are serving pizza!")

name = guests[4].title()
print(f"{name}, come to dinner at my place tonight, we got you a booster seat!")

name = guests[5].title()
print(f"{name}, I know you might have practice, but you should come to dinner at my house tonight.")

# %%
# TIY 3-7

guests = ['Malcolm X', 'George Lucas', 'Alexander the Great']

name = guests[0].title()
print(f"{name}, would you please come to my dinner tonight?")

name = guests[1].title()
print(f"{name}, my man! Dinner tonight at my house.")

name = guests[2].title()
print(f"{name}, I am having a dinner at my house tonight and I would love for you to come.")

name = guests[1].title()
print(f"\nSorry, {name} can't make it to dinner.")

del(guests[1])
guests.insert(1, 'J.R.R. Tolkein')

# Print the invitations again.
name = guests[0].title()
print(f"\n{name}, would you please come to my dinner tonight?")

name = guests[1].title()
print(f"{name}, my man! Dinner tonight at my house.")

name = guests[2].title()
print(f"{name}, I am having a dinner at my house tonight and I would love for you to come.")

print("\nWe got a bigger table for more guests!")
guests.insert(3, 'Leonardo Da Vinci')
guests.insert(4, 'Napoleon')
guests.append('Lebron James')


name = guests[0].title()
print(f"{name}, would you please come to my dinner tonight?")

name = guests[1].title()
print(f"{name}, my man! Dinner tonight at my house.")

name = guests[2].title()
print(f"{name}, I am having a dinner at my house tonight and I would love for you to come.")

name = guests[3].title()
print(f"{name}, come to my house for dinner tonight, we are serving pizza!")

name = guests[4].title()
print(f"{name}, come to dinner at my place tonight, we got you a booster seat!")

name = guests[5].title()
print(f"{name}, I know you might have practice, but you should come to dinner at my house tonight.")

print("\nSorry, we can only invite two people to dinner.")

name = guests.pop()
print(f"Sorry, {name.title()} there's no room at the table.")

name = guests.pop()
print(f"Sorry, {name.title()} there's no room at the table.")

name = guests.pop()
print(f"Sorry, {name.title()} there's no room at the table.")

name = guests.pop()
print(f"Sorry, {name.title()} there's no room at the table.")

name = guests[0].title()
print(f"{name}, please come to dinner.")

name = guests[1].title()
print(f"{name}, please come to dinner.")

del(guests[0])
del(guests[0])

print(guests)

# %%
# TIY 3-8

locations = ['Hawaii', 'Amalfi', 'Tokyo', 'Switzerland', 'California']

print("Original order:")
print(locations)

print("\nAlphabetical:")
print(sorted(locations))

print("\nOriginal order:")
print(locations)

print("\nReverse alphabetical:")
print(sorted(locations, reverse=True))

print("\nOriginal order:")
print(locations)

print("\nReversed:")
locations.reverse()
print(locations)

print("\nOriginal order:")
locations.reverse()
print(locations)

print("\nAlphabetical")
locations.sort()
print(locations)

print("\nReverse alphabetical")
locations.sort(reverse=True)
print(locations)
# Out:
# Original order:
# ['Hawaii', 'Amalfi', 'Tokyo', 'Switzerland', 'California']
#
# Alphabetical:
# ['Amalfi', 'California', 'Hawaii', 'Switzerland', 'Tokyo']
#
# Original order:
# ['Hawaii', 'Amalfi', 'Tokyo', 'Switzerland', 'California']
#
# Reverse alphabetical:
# ['Tokyo', 'Switzerland', 'Hawaii', 'California', 'Amalfi']
#
# Original order:
# ['Hawaii', 'Amalfi', 'Tokyo', 'Switzerland', 'California']
#
# Reversed:
# ['California', 'Switzerland', 'Tokyo', 'Amalfi', 'Hawaii']
#
# Original order:
# ['Hawaii', 'Amalfi', 'Tokyo', 'Switzerland', 'California']
#
# Alphabetical
# ['Amalfi', 'California', 'Hawaii', 'Switzerland', 'Tokyo']
#
# Reverse alphabetical
# ['Tokyo', 'Switzerland', 'Hawaii', 'California', 'Amalfi']

# %%
# TIY 3-9

guests = ['Malcolm X', 'George Lucas', 'Alexander the Great']

print(f"There are {len(guests)} guests coming.")
# Out:
# There are 3 guests coming.

# %%
# TIY 3-10

cities = ['Paris', 'NYC', 'Tokyo']

print("Original order:")
print(cities)

print("\nAlphabetical:")
print(sorted(cities))

print("\nOriginal order:")
print(cities)

print("\nReverse alphabetical:")
print(sorted(cities, reverse=True))

print("\nOriginal order:")
print(cities)

print("\nReversed:")
cities.reverse()
print(cities)

print("\nOriginal order:")
cities.reverse()
print(cities)

print("\nAlphabetical")
cities.sort()
print(cities)

print("\nReverse alphabetical")
cities.sort(reverse=True)
print(cities)

name = cities[0].title()
print(f"{name} is an incredible city")

name = cities[1].title()
print(f"{name} is an incredible city")

name = cities[2].title()
print(f"{name} is an incredible city")

name = cities[0].title()
print(f"{name} isn't as good as the other cities.")

del(cities[0])
cities.insert(1, 'Montreal')

name = cities[0].title()
print(f"{name} is an incredible city")

name = cities[1].title()
print(f"{name} is an incredible city")

name = cities[2].title()
print(f"{name} is an incredible city")

print("\nLets add some more cities!")
cities.insert(3, 'Hong Kong')
cities.append('Beijing')


name = cities[0].title()
print(f"{name} is an incredible city")

name = cities[1].title()
print(f"{name} is an incredible city")

name = cities[2].title()
print(f"{name} is an incredible city")

name = cities[3].title()
print(f"{name} is an incredible city")

name = cities[4].title()
print(f"{name} is an incredible city")

print("\nSorry, we have to pick the best city in the world.")

name = cities.pop()
print(f"Sorry, {name.title()} isn't the best city in the world.")

name = cities.pop()
print(f"Sorry, {name.title()} isn't the best city in the world.")

name = cities.pop()
print(f"Sorry, {name.title()} isn't the best city in the world.")

name = cities.pop()
print(f"Sorry, {name.title()} isn't the best city in the world.")

name = cities[0].title()
print(f"{name} is the best city in the world.")

print(cities)
print(f"There is {len(cities)} city left.")
# Out:
# Original order:
# ['Paris', 'NYC', 'Tokyo']
#
# Alphabetical:
# ['NYC', 'Paris', 'Tokyo']
#
# Original order:
# ['Paris', 'NYC', 'Tokyo']
#
# Reverse alphabetical:
# ['Tokyo', 'Paris', 'NYC']
#
# Original order:
# ['Paris', 'NYC', 'Tokyo']
#
# Reversed:
# ['Tokyo', 'NYC', 'Paris']
#
# Original order:
# ['Paris', 'NYC', 'Tokyo']
#
# Alphabetical
# ['NYC', 'Paris', 'Tokyo']
#
# Reverse alphabetical
# ['Tokyo', 'Paris', 'NYC']
# Tokyo is an incredible city
# Paris is an incredible city
# Nyc is an incredible city
# Tokyo isn't as good as the other cities.
# Paris is an incredible city
# Montreal is an incredible city
# Nyc is an incredible city
#
# Lets add some more cities!
# Paris is an incredible city
# Montreal is an incredible city
# Nyc is an incredible city
# Hong Kong is an incredible city
# Beijing is an incredible city
#
# Sorry, we have to pick the best city in the world.
# Sorry, Beijing isn't the best city in the world.
# Sorry, Hong Kong isn't the best city in the world.
# ...

# %%
# TIY 3-11

#Error:
#numbers = []
#print(numbers[-1])

#Solution:

numbers = ['1','2','3','4']
print(numbers[-1])
# Out:
# 4
